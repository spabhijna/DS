# %% [markdown]
# Name: Abhijna SP
#
# USN: 1BM23AI004
#
# Class: 3A

# %% [markdown]
# 1. Balanced Brackets

# %%
def is_balanced(s):
  stack = []
  bracket_map = {')':'(','}':'{',']':'['}
  for char in s:
    if char in ['(','{','[']:
      stack.append(char)

    elif char in [')','}',']']:
      if stack == [] or bracket_map[char]!=stack.pop():
        return False
  return True if not stack else False

# %%
s = '[{(()}]'
print(is_balanced(s))
# Out:
# False
